# %% [markdown]
# # NLTK: Language Models

# %%
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
words = sorted(set(text1))[280:]

# %%
fdist1 = FreqDist(text1)
fdist1.most_common(3)
# Out:
# [(',', 18713), ('the', 13721), ('.', 6862)]

# %%
list(bigrams(text1))
# Out:
# [('[', 'Moby'),
#  ('Moby', 'Dick'),
#  ('Dick', 'by'),
#  ('by', 'Herman'),
#  ('Herman', 'Melville'),
#  ('Melville', '1851'),
#  ('1851', ']'),
#  (']', 'ETYMOLOGY'),
#  ('ETYMOLOGY', '.'),
#  ('.', '('),
#  ('(', 'Supplied'),
#  ('Supplied', 'by'),
#  ('by', 'a'),
#  ('a', 'Late'),
#  ('Late', 'Consumptive'),
#  ('Consumptive', 'Usher'),
#  ('Usher', 'to'),
#  ('to', 'a'),
#  ('a', 'Grammar'),
#  ('Grammar', 'School'),
#  ('School', ')'),
#  (')', 'The'),
#  ('The', 'pale'),
#  ('pale', 'Usher'),
#  ('Usher', '--'),
#  ('--', 'threadbare'),
#  ('threadbare', 'in'),
#  ('in', 'coat'),
#  ('coat', ','),
#  (',', 'heart'),
#  ('heart', ','),
#  (',', 'body'),
#  ('body', ','),
#  (',', 'and'),
#  ('and', 'brain'),
#  ('brain', ';'),
#  (';', 'I'),
#  ('I', 'see'),
#  ('see', 'him'),
#  ('him', 'now'),
#  ('now', '.'),
#  ('.', 'He'),
#  ('He', 'was'),
#  ('was', 'ever'),
#  ('ever', 'dusting'),
#  ('dusting', 'his'),
#  ('his', 'old'),
#  ('old', 'lexicons'),
# ...

# %%
text1.collocations()
# Out:
# Sperm Whale; Moby Dick; White Whale; old man; Captain Ahab; sperm
# whale; Right Whale; Captain Peleg; New Bedford; Cape Horn; cried Ahab;
# years ago; lower jaw; never mind; Father Mapple; cried Stubb; chief
# mate; white whale; ivory leg; one hand

# %%
from nltk.util import ngrams
list(ngrams(text1, 3))
# Out:
# [('[', 'Moby', 'Dick'),
#  ('Moby', 'Dick', 'by'),
#  ('Dick', 'by', 'Herman'),
#  ('by', 'Herman', 'Melville'),
#  ('Herman', 'Melville', '1851'),
#  ('Melville', '1851', ']'),
#  ('1851', ']', 'ETYMOLOGY'),
#  (']', 'ETYMOLOGY', '.'),
#  ('ETYMOLOGY', '.', '('),
#  ('.', '(', 'Supplied'),
#  ('(', 'Supplied', 'by'),
#  ('Supplied', 'by', 'a'),
#  ('by', 'a', 'Late'),
#  ('a', 'Late', 'Consumptive'),
#  ('Late', 'Consumptive', 'Usher'),
#  ('Consumptive', 'Usher', 'to'),
#  ('Usher', 'to', 'a'),
#  ('to', 'a', 'Grammar'),
#  ('a', 'Grammar', 'School'),
#  ('Grammar', 'School', ')'),
#  ('School', ')', 'The'),
#  (')', 'The', 'pale'),
#  ('The', 'pale', 'Usher'),
#  ('pale', 'Usher', '--'),
#  ('Usher', '--', 'threadbare'),
#  ('--', 'threadbare', 'in'),
#  ('threadbare', 'in', 'coat'),
#  ('in', 'coat', ','),
#  ('coat', ',', 'heart'),
#  (',', 'heart', ','),
#  ('heart', ',', 'body'),
#  (',', 'body', ','),
#  ('body', ',', 'and'),
#  (',', 'and', 'brain'),
# ...

# %%
from nltk.collocations import *
TrigramCollocationFinder.from_words(text1).nbest(TrigramAssocMeasures().pmi, 10)
# Out:
# [('AFTER', 'EXCHANGING', 'HAILS'),
#  ('Anacharsis', 'Clootz', 'deputation'),
#  ('CAULKING', 'ITS', 'SEAMS'),
#  ('ELIZABETH', 'OAKES', 'SMITH'),
#  ('Et', 'tu', 'Brute'),
#  ('Ex', 'officio', 'professors'),
#  ('Fogo', 'Von', 'Slack'),
#  ('Ganders', 'formally', 'indite'),
#  ('Kentucky', 'Mammoth', 'Cave'),
#  ('LANTERNS', 'BUSILY', 'FILING')]

# %% [markdown]
# ## 10 frequently occuring Bigrams

# %%
list(bigrams(text1))[:10]
# Out:
# [('[', 'Moby'),
#  ('Moby', 'Dick'),
#  ('Dick', 'by'),
#  ('by', 'Herman'),
#  ('Herman', 'Melville'),
#  ('Melville', '1851'),
#  ('1851', ']'),
#  (']', 'ETYMOLOGY'),
#  ('ETYMOLOGY', '.'),
#  ('.', '(')]

# %%
list(bigrams(text2))[:10]
# Out:
# [('[', 'Sense'),
#  ('Sense', 'and'),
#  ('and', 'Sensibility'),
#  ('Sensibility', 'by'),
#  ('by', 'Jane'),
#  ('Jane', 'Austen'),
#  ('Austen', '1811'),
#  ('1811', ']'),
#  (']', 'CHAPTER'),
#  ('CHAPTER', '1')]

# %%
list(bigrams(text3))[:10]
# Out:
# [('In', 'the'),
#  ('the', 'beginning'),
#  ('beginning', 'God'),
#  ('God', 'created'),
#  ('created', 'the'),
#  ('the', 'heaven'),
#  ('heaven', 'and'),
#  ('and', 'the'),
#  ('the', 'earth'),
#  ('earth', '.')]

# %% [markdown]
# ## 5 frequently occuring Trigrams

# %%
from nltk.collocations import *
TrigramCollocationFinder.from_words(text1).nbest(TrigramAssocMeasures().pmi, 5)
# Out:
# [('AFTER', 'EXCHANGING', 'HAILS'),
#  ('Anacharsis', 'Clootz', 'deputation'),
#  ('CAULKING', 'ITS', 'SEAMS'),
#  ('ELIZABETH', 'OAKES', 'SMITH'),
#  ('Et', 'tu', 'Brute')]

# %%
TrigramCollocationFinder.from_words(text2).nbest(TrigramAssocMeasures().pmi, 5)
# Out:
# [('Austen', '1811', ']'),
#  ('Jane', 'Austen', '1811'),
#  ('200', 'L', 'per'),
#  ('Drury', 'Lane', 'lobby'),
#  ('L', 'per', 'annum')]

# %%
TrigramCollocationFinder.from_words(text3).nbest(TrigramAssocMeasures().pmi, 5)
# Out:
# [('olive', 'leaf', 'pluckt'),
#  ('sewed', 'fig', 'leaves'),
#  ('yield', 'royal', 'dainties'),
#  ('Fifteen', 'cubits', 'upward'),
#  ('leaf', 'pluckt', 'o')]

# %%
words_1 = sorted(set(text1))[280:]
words_2 = sorted(set(text2))[280:]
words_3 = sorted(set(text3))[280:]

# %% [markdown]
# ## Number of words with length > 16

# %%
longwords_1 = [w for w in words_1 if len(w) > 16]
longwords_2 = [w for w in words_2 if len(w) > 16]
longwords_3 = [w for w in words_3 if len(w) > 16]

# %%
print(len(longwords_1))
# Out:
# 11

# %%
print(len(longwords_2))
# Out:
# 3

# %%
print(len(longwords_3))
# Out:
# 0

# %% [markdown]
# ## Number of words with frequency > 500

# %%
high_freq_1 = [w for w in words_1 if fdist1[w] > 500]
high_freq_2 = [w for w in words_2 if fdist1[w] > 500]
high_freq_3 = [w for w in words_3 if fdist1[w] > 500]

# %%
print(len(high_freq_1))
print(len(high_freq_2))
print(len(high_freq_3))
# Out:
# 58
# 54
# 54

# %% [markdown]
# ## Number of words ending in “ed”

# %%
ed_words_1 = [w for w in words_1 if w.endswith('ed')]
ed_words_2 = [w for w in words_2 if w.endswith('ed')]
ed_words_3 = [w for w in words_3 if w.endswith('ed')]

# %%
print(len(ed_words_1))
print(len(ed_words_2))
print(len(ed_words_3))
# Out:
# 2196
# 897
# 275

# %%
import nltk

# %%
nltk.corpus.gutenberg.fileids()
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %%
gutenberg_sc = nltk.corpus.gutenberg.words('shakespeare-caesar.txt')

# %%
from nltk.corpus import brown
brown.words()
# Out:
# ['The', 'Fulton', 'County', 'Grand', 'Jury', 'said', ...]

# %%
/home/pheonix/University/Semester-7/NLP Tasks/Tasks/nltk_data/corpora

# %%
fai_txt = nltk.data.load('/home/pheonix/University/Semester-7/NLP Tasks/Tasks/nltk_data/corpora/faizan.txt', format ='raw')
fai_txt = nltk.data.load('/home/pheonix/University/Semester-7/NLP Tasks/Tasks/nltk_data/corpora/faizan.txt', format ='text')

# %%
from nltk.util import ngrams
words = nltk.word_tokenize(fai_txt)
fai_bigrams = list(ngrams(words, 2))
fai_trigrams = list(ngrams(words, 3))

# %%
print(fai_bigrams[:50])
# Out:
# [('PM', 'denies'), ('denies', 'knowledge'), ('knowledge', 'of'), ('of', 'AWB'), ('AWB', 'kickbacks'), ('kickbacks', 'The'), ('The', 'Prime'), ('Prime', 'Minister'), ('Minister', 'has'), ('has', 'denied'), ('denied', 'he'), ('he', 'knew'), ('knew', 'AWB'), ('AWB', 'was'), ('was', 'paying'), ('paying', 'kickbacks'), ('kickbacks', 'to'), ('to', 'Iraq'), ('Iraq', 'despite'), ('despite', 'writing'), ('writing', 'to'), ('to', 'the'), ('the', 'wheat'), ('wheat', 'exporter'), ('exporter', 'asking'), ('asking', 'to'), ('to', 'be'), ('be', 'kept'), ('kept', 'fully'), ('fully', 'informed'), ('informed', 'on'), ('on', 'Iraq'), ('Iraq', 'wheat'), ('wheat', 'sales'), ('sales', '.'), ('.', 'Letters'), ('Letters', 'from'), ('from', 'John'), ('John', 'Howard'), ('Howard', 'and'), ('and', 'Deputy'), ('Deputy', 'Prime'), ('Prime', 'Minister'), ('Minister', 'Mark'), ('Mark', 'Vaile'), ('Vaile', 'to'), ('to', 'AWB'), ('AWB', 'have'), ('have', 'been'), ('been', 'released')]

# %%
print(fai_trigrams[:50])
# Out:
# [('PM', 'denies', 'knowledge'), ('denies', 'knowledge', 'of'), ('knowledge', 'of', 'AWB'), ('of', 'AWB', 'kickbacks'), ('AWB', 'kickbacks', 'The'), ('kickbacks', 'The', 'Prime'), ('The', 'Prime', 'Minister'), ('Prime', 'Minister', 'has'), ('Minister', 'has', 'denied'), ('has', 'denied', 'he'), ('denied', 'he', 'knew'), ('he', 'knew', 'AWB'), ('knew', 'AWB', 'was'), ('AWB', 'was', 'paying'), ('was', 'paying', 'kickbacks'), ('paying', 'kickbacks', 'to'), ('kickbacks', 'to', 'Iraq'), ('to', 'Iraq', 'despite'), ('Iraq', 'despite', 'writing'), ('despite', 'writing', 'to'), ('writing', 'to', 'the'), ('to', 'the', 'wheat'), ('the', 'wheat', 'exporter'), ('wheat', 'exporter', 'asking'), ('exporter', 'asking', 'to'), ('asking', 'to', 'be'), ('to', 'be', 'kept'), ('be', 'kept', 'fully'), ('kept', 'fully', 'informed'), ('fully', 'informed', 'on'), ('informed', 'on', 'Iraq'), ('on', 'Iraq', 'wheat'), ('Iraq', 'wheat', 'sales'), ('wheat', 'sales', '.'), ('sales', '.', 'Letters'), ('.', 'Letters',
# ...

# %%
from nltk.corpus import PlaintextCorpusReader
import os
corpus_root = os.path.expanduser('/home/pheonix/University/Semester-7/NLP Tasks/Tasks/nltk_data/corpora/abc')
corpus = PlaintextCorpusReader(corpus_root, '.*', encoding='latin1')
wordlist = corpus.words()
print(len(wordlist))
bigramlist = list(ngrams(wordlist,2))
# Out:
# 766863

# %%
print(bigramlist[:50])
# Out:
# [('Australian', 'Broadcasting'), ('Broadcasting', 'Commission'), ('Commission', '2006'), ('2006', 'http'), ('http', '://'), ('://', 'www'), ('www', '.'), ('.', 'abc'), ('abc', '.'), ('.', 'net'), ('net', '.'), ('.', 'au'), ('au', '/'), ('/', 'Contents'), ('Contents', ':'), (':', '*'), ('*', 'Rural'), ('Rural', 'News'), ('News', 'http'), ('http', '://'), ('://', 'www'), ('www', '.'), ('.', 'abc'), ('abc', '.'), ('.', 'net'), ('net', '.'), ('.', 'au'), ('au', '/'), ('/', 'rural'), ('rural', '/'), ('/', 'news'), ('news', '/'), ('/', '*'), ('*', 'Science'), ('Science', 'News'), ('News', 'http'), ('http', '://'), ('://', 'www'), ('www', '.'), ('.', 'abc'), ('abc', '.'), ('.', 'net'), ('net', '.'), ('.', 'au'), ('au', '/'), ('/', 'science'), ('science', '/'), ('/', 'news'), ('news', '/'), ('/', 'PM')]

# %%
cfd = nltk.ConditionalFreqDist(bigramlist)

# %%
def generate_model(cfdist, word, num):
    for i in range(num):
        print(word, end=' ')
        word = cfdist[word].max()

# %%
generate_model(cfd, 'Broadcasting', 30)
# Out:
# Broadcasting Commission ( NFF ) and the first time , the first time , the first time , the first time , the first time , the first time ,

# %%
from nltk.corpus import PlaintextCorpusReader
import os
corpus_root = os.path.expanduser('/home/pheonix/University/Semester-7/NLP Tasks/Tasks/nltk_data/corpora/chat80')
corpus = PlaintextCorpusReader(corpus_root, '.*', encoding='latin1')
wordlist = corpus.words()
print(len(wordlist))
bigram = list(ngrams(wordlist,2))
# Out:
# 13795

# %%
print(bigram[:50])
# Out:
# [('The', 'various'), ('various', 'files'), ('files', 'which'), ('which', 'make'), ('make', 'up'), ('up', 'the'), ('the', 'program'), ('program', 'Chat'), ('Chat', '-'), ('-', '80'), ('80', '==================================================='), ('===================================================', '_________________________________________________________________________'), ('_________________________________________________________________________', '|'), ('|', 'Copyright'), ('Copyright', '('), ('(', 'C'), ('C', ')'), (')', '1982'), ('1982', '|'), ('|', '|'), ('|', '|'), ('|', '|'), ('|', 'David'), ('David', 'Warren'), ('Warren', ','), (',', '|'), ('|', '|'), ('|', 'SRI'), ('SRI', 'International'), ('International', ','), (',', '333'), ('333', 'Ravenswood'), ('Ravenswood', 'Ave'), ('Ave', '.,'), ('.,', 'Menlo'), ('Menlo', 'Park'), ('Park', ','), (',', '|'), ('|', '|'), ('|', 'California'), ('California', '94025'), ('94025', ','), (',', 'USA'), ('USA', ';'), (';', '|'), ('|', '|'),
# ...

# %%
cfd = nltk.ConditionalFreqDist(bigram)
def generate_model(cfdist, word, num):
    for i in range(num):
        print(word, end=' ')
        word = cfdist[word].max()

# %%
generate_model(cfd, 'various', 30)
# Out:
# various files which make up the | | | | | | | | | | | | | | | | | | | | | | | |

# %%
from nltk.corpus import PlaintextCorpusReader
import os
corpus_root = os.path.expanduser('/home/pheonix/University/Semester-7/NLP Tasks/Tasks/nltk_data/corpora/brown')
corpus = PlaintextCorpusReader(corpus_root, '.*', encoding='latin1')
wordlist = corpus.words()
print(len(wordlist))
bigram = list(ngrams(wordlist,2))
cfd = nltk.ConditionalFreqDist(bigram)
def generate_model(cfdist, word, num):
    for i in range(num):
        print(word, end=' ')
        word = cfdist[word].max()
# Out:
# 3369574

# %%
print(bigram[:50])
# Out:
# [('CONTENTS', 'This'), ('This', 'directory'), ('directory', 'contains'), ('contains', 'the'), ('the', 'Brown'), ('Brown', 'Corpus'), ('Corpus', ','), (',', 'in'), ('in', 'Form'), ('Form', 'C'), ('C', '('), ('(', 'tagged'), ('tagged', ').'), (').', 'Each'), ('Each', 'filename'), ('filename', 'consists'), ('consists', 'of'), ('of', 'a'), ('a', '"'), ('"', 'c'), ('c', '"'), ('"', '('), ('(', 'corpus'), ('corpus', 'form'), ('form', 'C'), ('C', '),'), ('),', 'followed'), ('followed', 'by'), ('by', 'a'), ('a', 'letter'), ('letter', 'a'), ('a', '-'), ('-', 'r'), ('r', 'designating'), ('designating', 'the'), ('the', 'genre'), ('genre', ','), (',', 'followed'), ('followed', 'by'), ('by', 'two'), ('two', 'digits'), ('digits', '.'), ('.', 'A'), ('A', '.'), ('.', 'PRESS'), ('PRESS', ':'), (':', 'REPORTAGE'), ('REPORTAGE', 'B'), ('B', '.'), ('.', 'PRESS')]

# %%
generate_model(cfd, 'directory', 30)
# Out:
# directory / nn of / nn of / nn of / nn of / nn of / nn of / nn of / nn of / nn of / nn
